# %%
import os
import sys
import importlib

# Setup package path for development
try:
    # For regular Python scripts
    current_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    # For Jupyter notebooks
    current_dir = os.getcwd()

# Add the parent directory to Python path
parent_dir = os.path.dirname(current_dir)
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# Force reload of the module to pick up recent changes
import PyHydroGeophysX.data_processing.ert_data_agent as ert_agent
importlib.reload(ert_agent)
    
from PyHydroGeophysX.data_processing.ert_data_agent import (
    load_ert_resipy, qc_and_visualize, export_for_inversion, LocalRef
)

ert = load_ert_resipy(
    project_dir="data/ERT/E4D",
    data_file="data/ERT/E4D/2021-10-08_1400.ohm",  # Full relative path from current directory
    instrument="E4D",      # explicit instrument
    crs="local",              # default; use crs="EPSG:32615", epsg=32615 for projected coords
    local_ref=LocalRef(origin_x=0.0, origin_y=0.0, azimuth_deg=90.0)
)
artifacts = qc_and_visualize(ert, outdir="results/ert_data_process")  # Changed from /results to results
bert_path = export_for_inversion(ert, outdir="results/ert_data_process", fmt="pgimli")
print("Artifacts:", artifacts)
print("BERT export:", bert_path)
# Out:
# Warning: gstools not installed. 3D kriging functionality will be limited.
# API path =  c:\Users\hchen117\.conda\envs\pg\Lib\site-packages\resipy
# ResIPy version =  3.6.3
# cR2.exe found and up to date.
# R3t.exe found and up to date.
# cR3t.exe found and up to date.
# Working directory is: c:\Users\hchen117\OneDrive - University of Iowa\Documents\GitHub\PyHydroGeophysX\examples\data\ERT\E4D
# Working directory is: C:\Users\hchen117\AppData\Local\Temp\resipy_9w1bwvpb
# E4D error column found
# filterData: 0 / 3647 quadrupoles removed.
# API path =  c:\Users\hchen117\.conda\envs\pg\Lib\site-packages\resipy
# ResIPy version =  3.6.3
# cR2.exe found and up to date.
# R3t.exe found and up to date.
# cR3t.exe found and up to date.
# Working directory is: c:\Users\hchen117\OneDrive - University of Iowa\Documents\GitHub\PyHydroGeophysX\examples\data\ERT\E4D
# Working directory is: C:\Users\hchen117\AppData\Local\Temp\resipy_9w1bwvpb
# E4D error column found
# filterData: 0 / 3647 quadrupoles removed.
# c:\Users\hchen117\OneDrive - University of Iowa\Documents\GitHub\PyHydroGeophysX\PyHydroGeophysX\data_processing\ert_data_agent.py:168: UserWarning: RESIPY cannot prepare project directory 'data/ERT/E4D' (PermissionError). Falling back to a temporary project directory.
#   warnings.warn(
# 0/3647 reciprocal measurements found.
# magErr/phiErr columns detected, will be used in protocol.dat
# Artifacts: {'electrodes_png': 'results\\ert_data_process\\electrodes.png', 'rhoa_hist_png': 'results\\ert_data_process\\rhoa_hist.png', 'observations_parquet': 'results\\ert_data_process\\observations.parquet', 'electrodes_csv': 'results\\ert_data_process\\electrodes.csv', 'standard_json': 'results\\ert_data_process\\ert_standard.json'}
# BERT export: results\ert_data_process\bert_data.dat
# Artifacts: {'electrodes_png': 'results\\ert_data_process\\electrodes.png', 'rhoa_hist_png': 'results\\ert_data_process\\rhoa_hist.png', 'observations_parquet': 'results\\ert_data_process\\observations.parquet', 'electrodes_csv': 'results\\ert_data_process\\electrodes.csv', 'standard_json': 'results\\ert_data_process\\ert_standard.json'}
# BERT export: results\ert_data_process\bert_data.dat

# %%
from PyHydroGeophysX.data_processing.ert_data_agent import (
    load_ert_resipy, qc_and_visualize, export_for_inversion, LocalRef
)

ert = load_ert_resipy(
    project_dir="data/ERT/E4D",
    data_file="2021-10-08_1400.ohm",
    instrument="E4D",      # explicit instrument
    crs="local",              # default; use crs="EPSG:32615", epsg=32615 for projected coords
    local_ref=LocalRef(origin_x=0.0, origin_y=0.0, azimuth_deg=90.0)
)
artifacts = qc_and_visualize(ert, outdir="/results/ert_data_process")
bert_path = export_for_inversion(ert, outdir="/results/ert_data_process", fmt="pgimli")
print("Artifacts:", artifacts)
print("BERT export:", bert_path)
# Out:
# Warning: gstools not installed. 3D kriging functionality will be limited.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from PyHydroGeophysX.data_processing.ert_data_agent import (
#       2     load_ert_resipy, qc_and_visualize, export_for_inversion, LocalRef
#       3 )
#       5 ert = load_ert_resipy(
#       6     project_dir="data/ERT/E4D",
#       7     data_file="2021-10-08_1400.ohm",
#    (...)     10     local_ref=LocalRef(origin_x=0.0, origin_y=0.0, azimuth_deg=90.0)
#      11 )
#      12 artifacts = qc_and_visualize(ert, outdir="/results/ert_data_process")
#
# ModuleNotFoundError: No module named 'PyHydroGeophysX.data_processing'

# %%
from PyHydroGeophysX.data_processing.ert_data_agent import load_ert_resipy, qc_and_visualize, export_for_inversion, LocalRef

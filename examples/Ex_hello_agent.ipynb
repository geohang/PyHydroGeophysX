# %% [markdown]
# # Hello Agent
#
# This notebook runs the no-LLM hello-world ERT path on bundled data. It does not require an API key.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if repo_root.name == "examples":
    repo_root = repo_root.parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from examples.Ex_hello_agent import run_hello_agent

result = run_hello_agent()
result.to_dict()
